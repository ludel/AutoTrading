# %%
import gym
import pandas as pd
from stable_baselines import A2C
from stable_baselines.common.policies import MlpPolicy

# %%
df = pd.read_csv('../data/mcphy_data.csv', index_col=0)

# %%
df.head()
# Out:
#             Open   High    Low  Close  Volume  Dividends  Stock Splits
# Date
# 2019-01-08  3.98  3.995  3.980  3.995       0          0             0
# 2019-01-08  3.99  3.995  3.990  3.995     186          0             0
# 2019-01-08  3.99  3.990  3.990  3.990       8          0             0
# 2019-01-09  4.00  4.055  4.000  4.055   14956          0             0
# 2019-01-09  4.10  4.250  4.095  4.175    7023          0             0

# %%
df = df.drop(['Dividends', 'Stock Splits'], axis=1)

# %%
custom_env = gym.make('forex-v0', df=df, window_size=10,
                      frame_bound=(10, 300), unit_side='right')

# %%
model = A2C(MlpPolicy, custom_env, verbose=1)
model.learn(total_timesteps=25000)
#model.save("a2c_cartpole")
# Out:
# Wrapping the env in a DummyVecEnv.
# WARNING:tensorflow:From /home/ludel/Workspace/IA/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/venv/lib64/python3.6/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/ludel/Workspace/IA/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/venv/lib64/python3.6/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/ludel/Workspace/IA/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/venv/lib64/python3.6/site-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/ludel/Workspace/IA/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/venv/lib64/python3.6/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/ludel/Workspace/IA/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/venv/lib64/python3.6/site-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /home/ludel/Workspace/IA/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/venv/lib64/python3.6/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/ludel/Workspace/IA/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/venv/lib64/python3.6/site-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/ludel/Workspace/IA/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/venv/lib64/python3.6/site-packages/stable_baselines/common/distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/ludel/Workspace/IA/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/venv/lib64/python3.6/site-packages/stable_baselines/common/distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/ludel/Workspace/IA/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/venv/lib64/python3.6/site-packages/stable_baselines/a2c/a2c.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/ludel/Workspace/IA/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/venv/lib64/python3.6/site-packages/stable_baselines/common/tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /home/ludel/Workspace/IA/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/venv/lib64/python3.6/site-packages/stable_baselines/common/tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/ludel/Workspace/IA/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/venv/lib64/python3.6/site-packages/tensorflow_core/python/ops/clip_ops.py:301: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/ludel/Workspace/IA/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/venv/lib64/python3.6/site-packages/stable_baselines/a2c/a2c.py:184: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From /home/ludel/Workspace/IA/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/venv/lib64/python3.6/site-packages/tensorflow_core/python/training/rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/ludel/Workspace/IA/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/venv/lib64/python3.6/site-packages/stable_baselines/a2c/a2c.py:194: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /home/ludel/Workspace/IA/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/venv/lib64/python3.6/site-packages/stable_baselines/a2c/a2c.py:196: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# ----------------------------------
# | explained_variance | -5.15e-05 |
# | fps                | 26        |
# | nupdates           | 1         |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 5         |
# | value_loss         | 4.87e+05  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -2.26e-06 |
# | fps                | 855       |
# | nupdates           | 100       |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 500       |
# | value_loss         | 2.19e+05  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -0.000109 |
# | fps                | 1033      |
# | nupdates           | 200       |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 1000      |
# | value_loss         | 7.14e+04  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000312 |
# | fps                | 1097     |
# | nupdates           | 300      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 1500     |
# | value_loss         | 1e+06    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.51e-05 |
# | fps                | 1135      |
# | nupdates           | 400       |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 2000      |
# | value_loss         | 5.99e+05  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -6.33e-05 |
# | fps                | 1157      |
# | nupdates           | 500       |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 2500      |
# | value_loss         | 5.86e+04  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -7.27e-06 |
# | fps                | 1174      |
# | nupdates           | 600       |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 3000      |
# | value_loss         | 2.35e+04  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -0.000261 |
# | fps                | 1181      |
# | nupdates           | 700       |
# | policy_entropy     | 0.679     |
# | total_timesteps    | 3500      |
# | value_loss         | 3.5e+04   |
# ----------------------------------
# ---------------------------------
# | explained_variance | 7.32e-05 |
# | fps                | 1185     |
# | nupdates           | 800      |
# | policy_entropy     | 0.643    |
# | total_timesteps    | 4000     |
# | value_loss         | 1.75e+05 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.29e-05 |
# | fps                | 1191      |
# | nupdates           | 900       |
# | policy_entropy     | 0.675     |
# | total_timesteps    | 4500      |
# | value_loss         | 6.37e+04  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 6.93e-05 |
# | fps                | 1191     |
# | nupdates           | 1000     |
# | policy_entropy     | 0.685    |
# | total_timesteps    | 5000     |
# | value_loss         | 2.92e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -4.7e-05 |
# | fps                | 1194     |
# | nupdates           | 1100     |
# | policy_entropy     | 0.635    |
# | total_timesteps    | 5500     |
# | value_loss         | 3.27e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 6.79e-06 |
# | fps                | 1185     |
# | nupdates           | 1200     |
# | policy_entropy     | 0.644    |
# | total_timesteps    | 6000     |
# | value_loss         | 3.64e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.23    |
# | fps                | 1174     |
# | nupdates           | 1300     |
# | policy_entropy     | 0.559    |
# | total_timesteps    | 6500     |
# | value_loss         | 0.00212  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.31e-05 |
# | fps                | 1170     |
# | nupdates           | 1400     |
# | policy_entropy     | 0.337    |
# | total_timesteps    | 7000     |
# | value_loss         | 2.15e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.28    |
# | fps                | 1170     |
# | nupdates           | 1500     |
# | policy_entropy     | 0.172    |
# | total_timesteps    | 7500     |
# | value_loss         | 0.000274 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -14      |
# | fps                | 1176     |
# | nupdates           | 1600     |
# | policy_entropy     | 0.162    |
# | total_timesteps    | 8000     |
# | value_loss         | 0.00107  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.57    |
# | fps                | 1183     |
# | nupdates           | 1700     |
# | policy_entropy     | 0.0804   |
# | total_timesteps    | 8500     |
# | value_loss         | 7.29e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.21    |
# | fps                | 1191     |
# | nupdates           | 1800     |
# | policy_entropy     | 0.0656   |
# | total_timesteps    | 9000     |
# | value_loss         | 3.66e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -4.39    |
# | fps                | 1200     |
# | nupdates           | 1900     |
# | policy_entropy     | 0.0569   |
# | total_timesteps    | 9500     |
# | value_loss         | 2.19e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -342     |
# | fps                | 1203     |
# | nupdates           | 2000     |
# | policy_entropy     | 0.0292   |
# | total_timesteps    | 10000    |
# | value_loss         | 0.000356 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -8.29    |
# | fps                | 1202     |
# | nupdates           | 2100     |
# | policy_entropy     | 0.0166   |
# | total_timesteps    | 10500    |
# | value_loss         | 7.89e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -20.8    |
# | fps                | 1205     |
# | nupdates           | 2200     |
# | policy_entropy     | 0.00924  |
# | total_timesteps    | 11000    |
# | value_loss         | 0.000483 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -561     |
# | fps                | 1203     |
# | nupdates           | 2300     |
# | policy_entropy     | 0.00702  |
# | total_timesteps    | 11500    |
# | value_loss         | 0.000111 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.707   |
# | fps                | 1201     |
# | nupdates           | 2400     |
# | policy_entropy     | 0.00445  |
# | total_timesteps    | 12000    |
# | value_loss         | 1.44e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -255     |
# | fps                | 1199     |
# | nupdates           | 2500     |
# | policy_entropy     | 0.00334  |
# | total_timesteps    | 12500    |
# | value_loss         | 0.00013  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1e+03   |
# | fps                | 1204     |
# | nupdates           | 2600     |
# | policy_entropy     | 0.00347  |
# | total_timesteps    | 13000    |
# | value_loss         | 2.97e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -304     |
# | fps                | 1206     |
# | nupdates           | 2700     |
# | policy_entropy     | 0.0038   |
# | total_timesteps    | 13500    |
# | value_loss         | 1.54e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.365   |
# | fps                | 1207     |
# | nupdates           | 2800     |
# | policy_entropy     | 0.00248  |
# | total_timesteps    | 14000    |
# | value_loss         | 3.2e-05  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -295     |
# | fps                | 1204     |
# | nupdates           | 2900     |
# | policy_entropy     | 0.00263  |
# | total_timesteps    | 14500    |
# | value_loss         | 3.62e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -215     |
# | fps                | 1206     |
# | nupdates           | 3000     |
# | policy_entropy     | 0.00269  |
# | total_timesteps    | 15000    |
# | value_loss         | 1.31e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -676     |
# | fps                | 1211     |
# | nupdates           | 3100     |
# | policy_entropy     | 0.00184  |
# | total_timesteps    | 15500    |
# | value_loss         | 4.52e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.15    |
# | fps                | 1214     |
# | nupdates           | 3200     |
# | policy_entropy     | 0.00189  |
# | total_timesteps    | 16000    |
# | value_loss         | 9.26e-07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -19.4    |
# | fps                | 1217     |
# | nupdates           | 3300     |
# | policy_entropy     | 0.002    |
# | total_timesteps    | 16500    |
# | value_loss         | 3.03e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.8e+03 |
# | fps                | 1221     |
# | nupdates           | 3400     |
# | policy_entropy     | 0.00206  |
# | total_timesteps    | 17000    |
# | value_loss         | 1.58e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -207     |
# | fps                | 1223     |
# | nupdates           | 3500     |
# | policy_entropy     | 0.0021   |
# | total_timesteps    | 17500    |
# | value_loss         | 3.41e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -119     |
# | fps                | 1222     |
# | nupdates           | 3600     |
# | policy_entropy     | 0.0022   |
# | total_timesteps    | 18000    |
# | value_loss         | 8.41e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.69    |
# | fps                | 1224     |
# | nupdates           | 3700     |
# | policy_entropy     | 0.00237  |
# | total_timesteps    | 18500    |
# | value_loss         | 2.78e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -56.9    |
# | fps                | 1225     |
# | nupdates           | 3800     |
# | policy_entropy     | 0.00245  |
# | total_timesteps    | 19000    |
# | value_loss         | 2.77e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -101     |
# | fps                | 1227     |
# | nupdates           | 3900     |
# | policy_entropy     | 0.00247  |
# | total_timesteps    | 19500    |
# | value_loss         | 7.35e-07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0162  |
# | fps                | 1230     |
# | nupdates           | 4000     |
# | policy_entropy     | 0.00156  |
# | total_timesteps    | 20000    |
# | value_loss         | 0.000109 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -275     |
# | fps                | 1232     |
# | nupdates           | 4100     |
# | policy_entropy     | 0.00157  |
# | total_timesteps    | 20500    |
# | value_loss         | 6.33e-07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -201     |
# | fps                | 1232     |
# | nupdates           | 4200     |
# | policy_entropy     | 0.00164  |
# | total_timesteps    | 21000    |
# | value_loss         | 9.45e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -60.6    |
# | fps                | 1232     |
# | nupdates           | 4300     |
# | policy_entropy     | 0.00167  |
# | total_timesteps    | 21500    |
# | value_loss         | 1.14e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -5.72    |
# | fps                | 1234     |
# | nupdates           | 4400     |
# | policy_entropy     | 0.00176  |
# | total_timesteps    | 22000    |
# | value_loss         | 3.97e-07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -6.09    |
# | fps                | 1237     |
# | nupdates           | 4500     |
# | policy_entropy     | 0.000954 |
# | total_timesteps    | 22500    |
# | value_loss         | 4.37e-07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -936     |
# | fps                | 1240     |
# | nupdates           | 4600     |
# | policy_entropy     | 0.00096  |
# | total_timesteps    | 23000    |
# | value_loss         | 1.72e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -607     |
# | fps                | 1241     |
# | nupdates           | 4700     |
# | policy_entropy     | 0.000993 |
# | total_timesteps    | 23500    |
# | value_loss         | 4.08e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -39.8    |
# | fps                | 1242     |
# | nupdates           | 4800     |
# | policy_entropy     | 0.00104  |
# | total_timesteps    | 24000    |
# | value_loss         | 4.12e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -169     |
# | fps                | 1243     |
# | nupdates           | 4900     |
# | policy_entropy     | 0.00104  |
# | total_timesteps    | 24500    |
# | value_loss         | 2.72e-06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -152     |
# | fps                | 1245     |
# | nupdates           | 5000     |
# | policy_entropy     | 0.00103  |
# | total_timesteps    | 25000    |
# | value_loss         | 5.72e-07 |
# ---------------------------------
